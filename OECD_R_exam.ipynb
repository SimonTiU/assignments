# %% [markdown]
# # Exam
#
# In this exam, we will work with the "frequently requested health data” from the OECD.
# Your task is to compute a simple “efficiency score” and make three plots.
#
#
# You will earn a higher grade if you provide nicer graphs.
#
# |name | student number|
# |----|----|
# |Simon Oudhoff| 1278559|

# %% [markdown]
# Now you need to call the libaries
#
# * ggplot2
# * dplyr

# %%
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# <i>I called the libraries gglot2 and dplyr.</i>
#
# Now you have to read the de data that we have cleaned during tutorial 3. The csv file is called oecddata.csv

# %%
oecd <- read.csv2("oecddata.csv")

# %% [markdown]
# <i>I loaded the csv file "oecddata.csv".</i>
#
# To see how the data look like, use the command:
#
# head(oecd)
#
# With the command
#
# oecd
#
#
# You can see the dataset in total.

# %%
head(oecd)
oecd
# Out:
#   X Country   Year Cost     LE
# 1 1 Australia 2005 2842.132 80.9
# 2 2 Australia 2006 3023.098 81.1
# 3 3 Australia 2007 3196.226 81.4
# 4 4 Australia 2008 3310.171 81.5
# 5 5 Australia 2009 3564.405 81.6
# 6 6 Australia 2010 3607.341 81.8
#     X   Country        Year Cost      LE
# 1    1  Australia      2005 2842.132  80.9
# 2    2  Australia      2006 3023.098  81.1
# 3    3  Australia      2007 3196.226  81.4
# 4    4  Australia      2008 3310.171  81.5
# 5    5  Australia      2009 3564.405  81.6
# 6    6  Australia      2010 3607.341  81.8
# 7    7  Australia      2011 3794.087  82.0
# 8    8  Australia      2012 3807.682  82.1
# 9    9  Australia      2013 4176.853  82.2
# 10  10  Australia      2014 4206.852  82.4
# 11  11  Australia      2015 4420.436    NA
# 12  12  Austria        2005 3324.079  79.4
# 13  13  Austria        2006 3567.649  80.0
# 14  14  Austria        2007 3718.739  80.3
# 15  15  Austria        2008 3964.849  80.5
# ...

# %% [markdown]
# ## Graphs

# %% [markdown]
# To make the graphs we need to make selections of the data. Please use "dplyr" (commands "select" and "filter") and the "pipe". The first assignment is to make a scatterplot using "ggplot". The graph contains data for all countries for the year 2014. Therefore make a dataframe with dplyr first, called "graph1" with the required data.
# Then, make a scatterplot with "Cost" on the x-axis and "LE" on the y-axis. You have to add a regression line with a shaded area for the confidence interval.

# %%
graph1 <- data.frame(oecd) %>% 
        select(Country, Year, LE, Cost) %>% 
        filter(Year == 2014) 
graph1
ggplot(graph1, aes(x = Cost, y = LE)) + geom_point() + geom_smooth(method=lm, col="yellow")
# Out:
#    Country         Year LE   Cost
# 1  Australia       2014 82.4 4206.8516
# 2  Austria         2014 81.6 4895.9992
# 3  Belgium         2014 81.4 4522.0450
# 4  Canada          2014   NA 4491.7648
# 5  Chile           2014 79.0 1688.5233
# 6  Czech Republic  2014 78.9 2386.3385
# 7  Denmark         2014 80.8 4857.0285
# 8  Estonia         2014 77.2 1724.5100
# 9  Finland         2014 81.3 3870.4000
# 10 France          2014 82.8 4366.9864
# 11 Germany         2014 81.2 5119.2146
# 12 Greece          2014 81.5 2220.1065
# 13 Hungary         2014 75.9 1796.6034
# 14 Iceland         2014 82.9 3896.9251
# 15 Ireland         2014 81.4 5001.3220
# 16 Israel          2014 82.2 2547.4010
# 17 Italy           2014 83.2 3206.8286
# 18 Japan           2014 83.7 4152.3727
# 19 Korea           2014 82.2 2361.4400
# 20 Latvia          2014 74.3 1295.0128
# 21 Luxembourg      2014 82.3 6682.2370
# 22 Mexico          2014 74.8 1035.3389
# 23 Netherlands     2014 81.8 5276.6003
# ...

# %% [markdown]
# <i>For graph1 I did select the data and used a pipe to get the required data of all countries for the year 2014 (for which I used filter)<br>
# For making the scatterplot I used "ggplot". I made my line yellow, because I liked it, by adding it in the geom_smooth (, col="yellow")</i>
#
# The second assignment is to make a line graph. You will use the years 2005-2015 for 5 countries (you can choose your own countries). Make a new dataframe called graph2 with the required data. Then, make a line graph with "Year"  and "Cost" on the y-axis. There should be coloured lines per country and a legend attached.
#
# <i>For graph2 I did select the data and used a pipe to get the required data of 5 nice countries (for which I used filter)<br>
# For the line graph I used "ggplot". I assumed that "Year" should be the x-axis and made "Cost" on the y-axis. At last, the legend telling us which country got which colour.</i>

# %%
graph2 <- data.frame(oecd) %>%
        select(Country, Year, Cost) %>%
        filter(Country %in% c('Netherlands', 'Belgium', 'Germany', 'Italy', 'Australia'))
graph2
ggplot(graph2, aes(x = Year , y = Cost, col=Country)) + geom_line()
# Out:
#    Country     Year Cost
# 1  Australia   2005 2842.132
# 2  Australia   2006 3023.098
# 3  Australia   2007 3196.226
# 4  Australia   2008 3310.171
# 5  Australia   2009 3564.405
# 6  Australia   2010 3607.341
# 7  Australia   2011 3794.087
# 8  Australia   2012 3807.682
# 9  Australia   2013 4176.853
# 10 Australia   2014 4206.852
# 11 Australia   2015 4420.436
# 12 Belgium     2005 2985.809
# 13 Belgium     2006 3136.916
# 14 Belgium     2007 3286.225
# 15 Belgium     2008 3542.354
# 16 Belgium     2009 3804.764
# 17 Belgium     2010 3901.913
# 18 Belgium     2011 4132.311
# 19 Belgium     2012 4286.412
# 20 Belgium     2013 4485.480
# 21 Belgium     2014 4522.045
# 22 Belgium     2015 4611.252
# 23 Germany     2005 3297.059
# 24 Germany     2006 3502.691
# 25 Germany     2007 3660.935
# 26 Germany     2008 3901.418
# 27 Germany     2009 4130.797
# 28 Germany     2010 4358.613
# 29 Germany     2011 4510.175
# 30 Germany     2012 4694.681
# 31 Germany     2013 4921.814
# ...

# %% [markdown]
# ## Efficiency scores
#
# The last assignment is to compute simple effiency scores. We will use the year 2014 for all countries (i.e. the dataframe "graph1").
# Make a new dateframe called "eff" (using graph1). Please use the "pipe" to execute to following steps:
# Select all the variables except the NA's (hint: use na.omit) and create a new column called "Ratio" with mutate. Ratio is defined as "Cost/LE" (cost per output).
# Create a new column called "Score" with mutate. Score is the ratio per country divided by the lowest ratio in the dataframe.
# To complete this dataframe order the dataset using "arrange" based on score (i.e. lowest Score first).
#
#
# Finally make a bar chart using ggplot. Countries should be on the x-axis and "Score" on the y-axis.
#
#
#
# You can earn extra points if you are able to order the graph based on scores (lowest first, highest last), if you are able to make the x-axis readable, make the bar of the Netherlands red and the other bars blue and/or change the name of the y-axis to "Efficiency scores according to [your name]"
#
#
# The figure should like this:
#
# ![My Figure](eff.png)

# %%
eff <- graph1 %>%
    filter(!is.na(LE)) %>%
    mutate(Ratio = Cost / LE) %>%
    mutate(Score = min(Ratio) / Ratio) %>%
    arrange(Score)
eff
# Out:
#    Country         Year LE   Cost      Ratio     Score
# 1  United States   2014 78.8 9024.2064 114.52039 0.1108515
# 2  Switzerland     2014 83.3 6786.5657  81.47138 0.1558186
# 3  Luxembourg      2014 82.3 6682.2370  81.19365 0.1563516
# 4  Norway          2014 82.2 6080.9980  73.97808 0.1716016
# 5  Netherlands     2014 81.8 5276.6003  64.50612 0.1967992
# 6  Germany         2014 81.2 5119.2146  63.04451 0.2013618
# 7  Sweden          2014 82.3 5065.1613  61.54509 0.2062675
# 8  Ireland         2014 81.4 5001.3220  61.44130 0.2066160
# 9  Denmark         2014 80.8 4857.0285  60.11174 0.2111859
# 10 Austria         2014 81.6 4895.9992  59.99999 0.2115793
# 11 Belgium         2014 81.4 4522.0450  55.55338 0.2285145
# 12 France          2014 82.8 4366.9864  52.74138 0.2406982
# 13 Australia       2014 82.4 4206.8516  51.05402 0.2486533
# 14 Japan           2014 83.7 4152.3727  49.61019 0.2558901
# 15 United Kingdom  2014 81.4 3971.3940  48.78862 0.2601991
# ...

# %% [markdown]
# <i> I made "eff" using graph1. I used filter to drop out the NA's, mutate to create "Ratio" and "Cost" and arrange on "Score" to get the desired order.</i>

# %%
eff.bar <- ggplot(eff, aes(x = reorder(Country,Score), y = Score, fill= Country)) +
        geom_bar(stat = "identity") +
        theme(text = element_text(size=12), axis.text.x = element_text(angle = 45, hjust = 1))+
        scale_fill_manual(values = c(rep("blue",21),rep("red",1),rep("blue",12))) +
        guides(fill=FALSE) +
        ylab("Efficiency scores according to Simon") +
        xlab("Country") 

eff.bar
# Out:
# plot without title

# %% [markdown]
# <i>And at last, the graph, which is, except for my name(Simon), the same as the graph according to Misja.</i>
